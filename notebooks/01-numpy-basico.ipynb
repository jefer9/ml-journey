# %% [markdown]
# # NumPy — Semana 1
#
# Consignas, no respuestas. El código lo escribís vos.
# Si algo te sorprende al ejecutar, anotalo: eso es material de nota.

# %%
import numpy as np

# %% [markdown]
# ## 1. Arrays y shapes
#
# Creá un array con las ventas de litros de cinco días.
# Después mirá su `.shape`, su `.dtype` y su `.ndim`.
#
# **Contestá con código:** ¿qué `shape` tiene un array de 5 números? ¿Por qué
# sale con una coma adentro?

# %% [markdown]
# ## 2. De vector a matriz
#
# Ahora cinco días **por tres productos**: queso, suero, mantequilla.
#
# Creá esa tabla como array 2D. Mirá el `shape`.
# Sacá: la fila del día 3, la columna del queso, y el dato del día 2 / producto 1.
#
# **Contestá:** en `a[2, 1]`, ¿cuál de los dos números es la fila?

# %% [markdown]
# ## 3. Vectorizado vs. bucle (medí, no supongas)
#
# Creá un array de 1.000.000 de precios con `np.random.rand`.
#
# Multiplicá todo por 1.19 (el IVA) de dos formas:
# 1. Con un `for` sobre una lista de Python.
# 2. Con NumPy, en una línea.
#
# Cronometrá las dos con `time.perf_counter()`. **Anotá el número que te dio.**
# Ayer lo dedujiste en teoría; acá lo vas a ver.

# %% [markdown]
# ## 4. Broadcasting
#
# Tenés la tabla de 5 días × 3 productos del punto 2.
#
# Subile el precio a los tres productos, cada uno con un porcentaje distinto,
# usando un array de 3 elementos y **una sola operación**. Sin bucles.
#
# Después probá lo mismo con un array de 4 elementos y mirá el error.
#
# **La pregunta:** ¿por qué anduvo con 3 y falló con 4?

# %% [markdown]
# ## 5. La trampa
#
# Corré esto y mirá el `dtype` del resultado:
#
# ```python
# np.array([3.5, 12000, 'queso costeño'])
# ```
#
# Después intentá multiplicar ese array por 2.
#
# **La pregunta:** en el CSV de la cremería hay un `"N/A"` en la columna de
# precios. ¿Qué pasa con los otros 49.999 precios? ¿Te avisa alguien?

# %% [markdown]
# ---
#
# ## Qué me sorprendió
#
# *(3 líneas máximo. De acá salen las notas de concepto.)*
#
# -
